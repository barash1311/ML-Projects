# %% [markdown]
# ### seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
#basic plotting using seaborn
tips=sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
## create a scatter plot
import matplotlib as plt
sns.scatterplot(x="total_bill",y="tip",data=tips)
plt.title("scatter plot")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 4
#       2 import matplotlib as plt
#       3 sns.scatterplot(x="total_bill",y="tip",data=tips)
# ----> 4 plt.title("scatter plot")
#       5 plt.show()
#
# File c:\Users\b12b3\Desktop\ML\ML-Projects\Environments\venv\Lib\site-packages\matplotlib\_api\__init__.py:218, in caching_module_getattr.<locals>.__getattr__(name)
#     216 if name in props:
#     217     return props[name].__get__(instance)
# --> 218 raise AttributeError(
#     219     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'title'

# %%
## line plt
sns.lineplot(x="size",y="total_bill",data=tips)
plt.title("total bill")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 3
#       1 ## line plt
#       2 sns.lineplot(x="size",y="total_bill",data=tips)
# ----> 3 plt.title("total bill")
#
# File c:\Users\b12b3\Desktop\ML\ML-Projects\Environments\venv\Lib\site-packages\matplotlib\_api\__init__.py:218, in caching_module_getattr.<locals>.__getattr__(name)
#     216 if name in props:
#     217     return props[name].__get__(instance)
# --> 218 raise AttributeError(
#     219     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'title'

# %%
sns.barplot(x="day",y="total_bill",data=tips)
plt.title("heading")
plt.show()

# %%
## box plot
sns.boxplot(x="day",y="total_bill",data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
## voilin plt
sns.violinplot(x="day",y="total_bill",data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
### histograms
sns.histplot(tips["total_bill"],bins=10,kde=False)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
##kde plot
sns.kdeplot(tips["total_bill"],fill=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
## pair plot-->relatinship
sns.pairplot(tips)

# %%
## heat map
corr=tips[["total_bill","tip","size"]].corr()
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
sales_df=pd.read_csv("./SaleData.csv")
sales_df.head(5)
# Out:
#   OrderDate   Region  Manager   SalesMan          Item  Units  Unit_price   \
# 0    1/6/18     East   Martha  Alexander    Television   95.0    1,198.00
# 1   1/23/18  Central  Hermann     Shelli  Home Theater   50.0      500.00
# 2    2/9/18  Central  Hermann       Luis    Television   36.0    1,198.00
# 3   2/26/18  Central  Timothy      David    Cell Phone   27.0      225.00
# 4   3/15/18     West  Timothy    Stephen    Television   56.0    1,198.00
#
#        Sale_amt
# 0   113,810.00
# 1    25,000.00
# 2    43,128.00
# 3     6,075.00
# 4    67,088.00

# %%
plt.figure(figsize=(10,6))
sns.barplot(x="Item",y="Sale_amt",data=sales_df,estimator=sum)
plt.xlabel("sds")
plt.ylabel("shs")
# Out:
# Text(0, 0.5, 'shs')
