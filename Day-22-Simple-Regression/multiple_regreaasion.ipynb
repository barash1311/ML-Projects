# %%
import pandas as pd
import numpy as np

# Generate sample data
np.random.seed(0)  # For reproducibility
data = {
    'Year': np.random.choice([2020, 2021, 2022], size=50),
    'Month': np.random.randint(1, 13, size=50),  # Numeric months
    'Interest_Rate': np.random.uniform(1.0, 3.0, size=50).round(2),
    'Unemployment_Rate': np.random.uniform(3.0, 7.0, size=50).round(2),
    'Index_Price': np.random.randint(2500, 4000, size=50)
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Save to Excel
df.to_excel('sample_data_numeric_month.xlsx', index=False)

print("Data saved to 'sample_data_numeric_month.xlsx'")
# Out:
# Data saved to 'sample_data_numeric_month.xlsx'

# %%
import pandas as pd
import numpy as np
#generating a sample data
np.random.seed(0)
data={
    'Year': np.random.choice([2020, 2021, 2022], size=50),
    "month":np.random.randint(1,13,size=50),
    'Interest_Rate': np.random.uniform(1.0, 3.0, size=50).round(2),
    "unemployment_rate":np.random.uniform(1.0,5.0,size=50).round(2),
    "index_price":np.random.randint(2500,4000,size=50)
}
df=pd.DataFrame(data)
df.to_excel("intereset.xlsx",index=True)

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_excel('intereset.xlsx')

# %%
df.head()
# Out:
#    Unnamed: 0  Year  month  Interest_Rate  unemployment_rate  index_price
# 0           0  2020      5           1.19               3.77         3568
# 1           1  2021      2           2.95               3.90         3302
# 2           2  2020      5           1.94               3.01         3612
# 3           3  2021     10           2.95               4.82         2533
# 4           4  2021     11           2.21               3.58         3145

# %%
#drop the unnecdessay colimn
df.drop(columns=["Unnamed: 0","Year","month"],axis=1,inplace=True)

# %%
df
# Out:
#     Interest_Rate  unemployment_rate  index_price
# 0            1.19               3.77         3568
# 1            2.95               3.90         3302
# 2            1.94               3.01         3612
# 3            2.95               4.82         2533
# 4            2.21               3.58         3145
# 5            2.48               2.70         2732
# 6            1.08               3.43         3267
# 7            1.57               1.08         2536
# 8            1.24               2.21         3983
# 9            1.59               3.64         2790
# 10           1.24               2.16         2697
# 11           1.64               3.47         3394
# 12           1.83               2.72         3778
# 13           1.13               1.54         3604
# 14           2.38               2.19         3970
# 15           2.13               3.28         2636
# 16           1.53               3.36         2689
# 17           2.05               3.30         2629
# ...

# %%
df.isnull().sum()
#checking the null value
# Out:
# Interest_Rate        0
# unemployment_rate    0
# index_price          0
# dtype: int64

# %%
#two independent and one depenedent feauture
#liets do some visualization
sns.pairplot(df)

# %%
df.corr()
# Out:
#                    Interest_Rate  unemployment_rate  index_price
# Interest_Rate           1.000000          -0.080089    -0.050533
# unemployment_rate      -0.080089           1.000000    -0.099409
# index_price            -0.050533          -0.099409     1.000000

# %%
##ivsualize the datapoints
plt.scatter(df["Interest_Rate"],df["unemployment_rate"],color="red")
plt.xlabel("interest_Rate")
plt.ylabel("uneplyment")
# Out:
# Text(0, 0.5, 'uneplyment')

# %%
##indenependent and depenedent
X=df[["Interest_Rate","unemployment_rate"]]##next will the better wat

# %%
X=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
X.head()
# Out:
#    Interest_Rate  unemployment_rate
# 0           1.19               3.77
# 1           2.95               3.90
# 2           1.94               3.01
# 3           2.95               4.82
# 4           2.21               3.58

# %%
y
# Out:
# 0     3568
# 1     3302
# 2     3612
# 3     2533
# 4     3145
# 5     2732
# 6     3267
# 7     2536
# 8     3983
# 9     2790
# 10    2697
# 11    3394
# 12    3778
# 13    3604
# 14    3970
# 15    2636
# 16    2689
# 17    2629
# 18    2709
# 19    3892
# 20    2791
# 21    3900
# 22    3871
# 23    2668
# 24    3304
# 25    2676
# 26    2823
# 27    3008
# 28    3303
# 29    3638
# 30    3553
# 31    3813
# 32    2646
# 33    3797
# 34    2721
# 35    2840
# 36    3009
# 37    3014
# 38    2569
# 39    3881
# 40    3408
# 41    3056
# 42    3385
# 43    3265
# 44    3846
# 45    2591
# 46    3865
# 47    2923
# 48    3938
# 49    3210
# Name: index_price, dtype: int64

# %%
##train test split
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.15,random_state=42)

# %%
##new plot
import seaborn as sns
sns.regplot(x=df["Interest_Rate"],y=df["index_price"],color="red")
# Out:
# <Axes: xlabel='Interest_Rate', ylabel='index_price'>

# %%
## standrad sclar
from sklearn.preprocessing import StandardScaler

# %%
scalar=StandardScaler()
X_test=scalar.fit_transform(X_test)
X_train=scalar.fit_transform(X_train)

# %%
from sklearn.linear_model import LinearRegression
regression=LinearRegression()

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.model_selection import cross_val_score
validation=cross_val_score(regression,X_train,y_train,scoring="neg_mean_squared_error",cv=3)

# %%
validation
# Out:
# array([-303362.52081397, -242383.91533423, -377161.82605598])

# %%
np.mean(validation)
# Out:
# np.float64(-307636.0874013928)

# %%
##prediction
y_pred=regression.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
rmse=np.sqrt(mse)
print(mse)
print(mae)
print(rmse)
# Out:
# 308493.6912852046
# 538.7806195329505
# 555.4220839012477

# %%
##assumption
##r square
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)
print(score)
1-(1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# -0.024585853516468026
# -0.4344201949230553

# %%
##assumptions
plt.scatter(y_test,y_pred)

# %%
residulas=y_test-y_pred

# %%
sns.displot(residulas,kind="kde")

# %%
##scatter plot wrt prediction as residuals
plt.scatter(y_pred,residulas)
