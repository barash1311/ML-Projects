# %%
import pandas as pd

# %%
df=pd.read_csv("SaleData.csv")
df.head(5)
# Out:
#   OrderDate   Region  Manager   SalesMan          Item  Units  Unit_price   \
# 0    1/6/18     East   Martha  Alexander    Television   95.0    1,198.00
# 1   1/23/18  Central  Hermann     Shelli  Home Theater   50.0      500.00
# 2    2/9/18  Central  Hermann       Luis    Television   36.0    1,198.00
# 3   2/26/18  Central  Timothy      David    Cell Phone   27.0      225.00
# 4   3/15/18     West  Timothy    Stephen    Television   56.0    1,198.00
#
#        Sale_amt
# 0   113,810.00
# 1    25,000.00
# 2    43,128.00
# 3     6,075.00
# 4    67,088.00

# %%
df.tail(5)
# Out:
#    OrderDate   Region  Manager SalesMan          Item   Units  Unit_price   \
# 40  11/17/19  Central  Hermann     Luis  Home Theater   11.00      500.00
# 41   12/4/19  Central  Hermann     Luis  Home Theater   94.00      500.00
# 42  12/21/19  Central   Martha   Steven  Home Theater   28.00      500.00
# 43       NaN      NaN      NaN      NaN           NaN  278.00    1,125.00
# 44       NaN      NaN      NaN      NaN           NaN   34.75      140.63
#
#        Sale_amt
# 40    5,500.00
# 41   47,000.00
# 42   14,000.00
# 43   62,550.00
# 44    7,818.75

# %%
df.describe()
# Out:
#             Units
# count   45.000000
# mean    54.083333
# std     45.096676
# min      2.000000
# 25%     28.000000
# 50%     53.000000
# 75%     75.000000
# max    278.000000

# %%
df.dtypes
# Out:
# OrderDate        object
# Region           object
# Manager          object
# SalesMan         object
# Item             object
# Units           float64
#  Unit_price      object
# Sale_amt         object
# dtype: object

# %%
### handeling missing values
df.isnull().any()
# Out:
# OrderDate        True
# Region           True
# Manager          True
# SalesMan         True
# Item             True
# Units           False
#  Unit_price     False
# Sale_amt        False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# OrderDate       2
# Region          2
# Manager         2
# SalesMan        2
# Item            2
# Units           0
#  Unit_price     0
# Sale_amt        0
# dtype: int64

# %%
df_filled=df.fillna(0)

# %%
### filling missvalues wit the mean of the column
df
# Out:
#    OrderDate   Region  Manager   SalesMan          Item   Units  Unit_price   \
# 0     1/6/18     East   Martha  Alexander    Television   95.00    1,198.00
# 1    1/23/18  Central  Hermann     Shelli  Home Theater   50.00      500.00
# 2     2/9/18  Central  Hermann       Luis    Television   36.00    1,198.00
# 3    2/26/18  Central  Timothy      David    Cell Phone   27.00      225.00
# 4    3/15/18     West  Timothy    Stephen    Television   56.00    1,198.00
# 5     4/1/18     East   Martha  Alexander  Home Theater   60.00      500.00
# 6    4/18/18  Central   Martha     Steven    Television   75.00    1,198.00
# 7     5/5/18  Central  Hermann       Luis    Television   90.00    1,198.00
# 8    5/22/18     West  Douglas    Michael    Television   32.00    1,198.00
# 9     6/8/18     East   Martha  Alexander  Home Theater   60.00      500.00
# 10   6/25/18  Central  Hermann      Sigal    Television   90.00    1,198.00
# ...

# %%
df.isnull().sum()
# Out:
# OrderDate       2
# Region          2
# Manager         2
# SalesMan        2
# Item            2
# Units           0
#  Unit_price     0
# Sale_amt        0
# dtype: int64

# %%
df["IT"]=df["Item"].fillna("temp")

# %%
df
# Out:
#    OrderDate   Region  Manager   SalesMan          Item   Units  Unit_price   \
# 0     1/6/18     East   Martha  Alexander    Television   95.00    1,198.00
# 1    1/23/18  Central  Hermann     Shelli  Home Theater   50.00      500.00
# 2     2/9/18  Central  Hermann       Luis    Television   36.00    1,198.00
# 3    2/26/18  Central  Timothy      David    Cell Phone   27.00      225.00
# 4    3/15/18     West  Timothy    Stephen    Television   56.00    1,198.00
# 5     4/1/18     East   Martha  Alexander  Home Theater   60.00      500.00
# 6    4/18/18  Central   Martha     Steven    Television   75.00    1,198.00
# 7     5/5/18  Central  Hermann       Luis    Television   90.00    1,198.00
# 8    5/22/18     West  Douglas    Michael    Television   32.00    1,198.00
# 9     6/8/18     East   Martha  Alexander  Home Theater   60.00      500.00
# 10   6/25/18  Central  Hermann      Sigal    Television   90.00    1,198.00
# ...

# %%
df.dtypes
# Out:
# OrderDate        object
# Region           object
# Manager          object
# SalesMan         object
# Item             object
# Units           float64
#  Unit_price      object
# Sale_amt         object
# IT               object
# dtype: object

# %%
### renaming column
df.rename(columns={"OrderDate":"date"})
# Out:
#         date   Region  Manager   SalesMan          Item   Units  Unit_price   \
# 0     1/6/18     East   Martha  Alexander    Television   95.00    1,198.00
# 1    1/23/18  Central  Hermann     Shelli  Home Theater   50.00      500.00
# 2     2/9/18  Central  Hermann       Luis    Television   36.00    1,198.00
# 3    2/26/18  Central  Timothy      David    Cell Phone   27.00      225.00
# 4    3/15/18     West  Timothy    Stephen    Television   56.00    1,198.00
# 5     4/1/18     East   Martha  Alexander  Home Theater   60.00      500.00
# 6    4/18/18  Central   Martha     Steven    Television   75.00    1,198.00
# 7     5/5/18  Central  Hermann       Luis    Television   90.00    1,198.00
# 8    5/22/18     West  Douglas    Michael    Television   32.00    1,198.00
# 9     6/8/18     East   Martha  Alexander  Home Theater   60.00      500.00
# 10   6/25/18  Central  Hermann      Sigal    Television   90.00    1,198.00
# ...

# %%
##change data type
df
# Out:
#    OrderDate   Region  Manager   SalesMan          Item   Units  Unit_price   \
# 0     1/6/18     East   Martha  Alexander    Television   95.00    1,198.00
# 1    1/23/18  Central  Hermann     Shelli  Home Theater   50.00      500.00
# 2     2/9/18  Central  Hermann       Luis    Television   36.00    1,198.00
# 3    2/26/18  Central  Timothy      David    Cell Phone   27.00      225.00
# 4    3/15/18     West  Timothy    Stephen    Television   56.00    1,198.00
# 5     4/1/18     East   Martha  Alexander  Home Theater   60.00      500.00
# 6    4/18/18  Central   Martha     Steven    Television   75.00    1,198.00
# 7     5/5/18  Central  Hermann       Luis    Television   90.00    1,198.00
# 8    5/22/18     West  Douglas    Michael    Television   32.00    1,198.00
# 9     6/8/18     East   Martha  Alexander  Home Theater   60.00      500.00
# 10   6/25/18  Central  Hermann      Sigal    Television   90.00    1,198.00
# ...

# %%
total["Units"]=df["Units"].astype(int)
total
# Out:
# 0                                                       95
# 1                                                       50
# 2                                                       36
# 3                                                       27
# 4                                                       56
# 5                                                       60
# 6                                                       75
# 7                                                       90
# 8                                                       32
# 9                                                       60
# 10                                                      90
# 11                                                      29
# 12                                                      81
# 13                                                      35
# 14                                                       2
# 15                                                      16
# ...

# %%
total
# Out:
# 0                                                       95
# 1                                                       50
# 2                                                       36
# 3                                                       27
# 4                                                       56
# 5                                                       60
# 6                                                       75
# 7                                                       90
# 8                                                       32
# 9                                                       60
# 10                                                      90
# 11                                                      29
# 12                                                      81
# 13                                                      35
# 14                                                       2
# 15                                                      16
# ...

# %%
df["New value"]=df["Units"].apply(lambda x:x*2)

# %%
df
# Out:
#    OrderDate   Region  Manager   SalesMan          Item   Units  Unit_price   \
# 0     1/6/18     East   Martha  Alexander    Television   95.00    1,198.00
# 1    1/23/18  Central  Hermann     Shelli  Home Theater   50.00      500.00
# 2     2/9/18  Central  Hermann       Luis    Television   36.00    1,198.00
# 3    2/26/18  Central  Timothy      David    Cell Phone   27.00      225.00
# 4    3/15/18     West  Timothy    Stephen    Television   56.00    1,198.00
# 5     4/1/18     East   Martha  Alexander  Home Theater   60.00      500.00
# 6    4/18/18  Central   Martha     Steven    Television   75.00    1,198.00
# 7     5/5/18  Central  Hermann       Luis    Television   90.00    1,198.00
# 8    5/22/18     West  Douglas    Michael    Television   32.00    1,198.00
# 9     6/8/18     East   Martha  Alexander  Home Theater   60.00      500.00
# 10   6/25/18  Central  Hermann      Sigal    Television   90.00    1,198.00
# ...

# %%
## data aggreegarting and gruoping
grouned=df.groupby("Item")["Unit"].mean()
print(grouned)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 2
#       1 ## data aggreegarting and gruoping
# ----> 2 grouned=df.groupby("Item")["Unit"].mean()
#       3 print(grouned)
#
# File c:\Users\b12b3\Desktop\ML\ML-Projects\Environments\venv\Lib\site-packages\pandas\core\groupby\generic.py:1951, in DataFrameGroupBy.__getitem__(self, key)
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
#    1947     raise ValueError(
#    1948         "Cannot subset columns with a tuple with more than one element. "
#    1949         "Use a list instead."
#    1950     )
# -> 1951 return super().__getitem__(key)
#
# ...

# %%
df.groupby(["Item","Region"])["Units"].sum()
# Out:
# Item          Region
# Cell Phone    Central     27.0
#               East       175.0
#               West        76.0
# Desk          Central      7.0
#               West         3.0
# Home Theater  Central    424.0
#               East       234.0
#               West        64.0
# Television    Central    498.0
#               East       130.0
#               West        88.0
# Video Games   Central    243.0
#               East       152.0
# Name: Units, dtype: float64

# %%
## aggregate multiple function
df.groupby("Region")["Units"].agg(["mean","sum","count"])
# Out:
#               mean     sum  count
# Region
# Central  49.958333  1199.0     24
# East     53.153846   691.0     13
# West     38.500000   231.0      6

# %%
## merging and joinigng data frames

# %%
d1=pd.DataFrame({"key":["A","B","C"],"value1":[1,2,3]})
d2=pd.DataFrame({"key":["A","B","D"],"value2":[4,5,6]})
d1
# Out:
#   key  value1
# 0   A       1
# 1   B       2
# 2   C       3

# %%
## merge dat frame on key coumns
pd.merge(d1,d2,on="key",how="right")
pd.merge(d1,d2,on="key",how="left")
pd.merge(d1,d2,on="key",how="inner")
pd.merge(d1,d2,on="key",how="outer")
# Out:
#   key  value1  value2
# 0   A     1.0     4.0
# 1   B     2.0     5.0
# 2   C     3.0     NaN
# 3   D     NaN     6.0
